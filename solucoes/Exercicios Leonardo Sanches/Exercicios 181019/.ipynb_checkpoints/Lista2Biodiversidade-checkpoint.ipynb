# %%
import pandas as pd
import os
print(os.getcwd())
data = pd.read_csv("./portalbio_export_16-10-2019-14-39-54.csv", sep=";")

#print(data.loc[:,["Latitude"]])
#print(data.iloc[:,[0]])
# Out:
# /home/leleopc/Documentos/Exercicios Hub/Exercicios 181019

# %%
#Para cada coluna identique a quantidade de linhas com dados faltantes 
#(em alguns casos, o dado faltante é uma string vazia, em outros casos é uma string contendo 
#algum valor do tipo: "sem informação"). 
#Faça um método que retorna a média de dados faltantes por coluna

def itemFatante(itensValues):
    faltantePorColuna = {}
    for row in itensValues:
        for i in range(len(row)):
            if row[i] == "" or str(row[i]).lower() == "sem informações":
                if i in faltantePorColuna:
                    faltantePorColuna[i] += 1
                else:
                    faltantePorColuna[i] = 1
    return faltantePorColuna

itensDataFaltante = itemFatante(data.values)
itensHash = data.keys()

for i in range(len(itensHash)):
    if i in list(itensDataFaltante.keys()):
        print(itensHash[i]+ " - media de: " + str(round(((itensDataFaltante[i] / int(len(data.values))) * 100),2)) + "% de campos nulos ou vazios.")
# Out:
# Nome da instituicao - media de: 100.0% de campos nulos ou vazios.
# Responsavel pelo registro - media de: 0.08% de campos nulos ou vazios.
# Numero do registro na base de dados - media de: 6.01% de campos nulos ou vazios.
# Data do registro - media de: 3.5% de campos nulos ou vazios.
# Data do evento - media de: 54.45% de campos nulos ou vazios.
# Nome cientifico - media de: 1.69% de campos nulos ou vazios.
# Nome comum - media de: 74.21% de campos nulos ou vazios.
# Nivel taxonomico - media de: 1.69% de campos nulos ou vazios.
# Numero de individuos - media de: 51.35% de campos nulos ou vazios.
# Reino - media de: 100.0% de campos nulos ou vazios.
# Filo - media de: 3.17% de campos nulos ou vazios.
# Classe - media de: 3.76% de campos nulos ou vazios.
# Ordem - media de: 4.29% de campos nulos ou vazios.
# Familia - media de: 4.73% de campos nulos ou vazios.
# Genero - media de: 16.51% de campos nulos ou vazios.
# Especie - media de: 37.45% de campos nulos ou vazios.
# Categoria de Ameaca - media de: 85.12% de campos nulos ou vazios.
# Localidade - media de: 1.94% de campos nulos ou vazios.
# Pais - media de: 3.43% de campos nulos ou vazios.
# Estado/Provincia - media de: 10.56% de campos nulos ou vazios.
# Municipio - media de: 42.13% de campos nulos ou vazios.
# Outras informacoes da localidade - media de: 55.8% de campos nulos ou vazios.
# Jurisdicao - media de: 100.0% de campos nulos ou vazios.
# Destino do Material - media de: 55.01% de campos nulos ou vazios.

# %%
def buscaPorEstadoEspecieAmeaca(data, estado, especie, ameaca):
    for row in data.values:
        if row[26] == estado and row[22] == ameaca and row[11] == especie:
            return [row[29], row[30]]
            break
    return "Nao encontrada."
        
def buscaTodosMarcacoes(data):
    latLong = []
    for row in data.values:
        latLong.append([row[29], row[30]])
    return latLong
    
busca = buscaTodosMarcacoes(data)
# Out:
# [[-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.8489999999999998, -32.42], [-3.85, -32.42], [-3.86, -32.42], [-20.5142, -29.3064], [-20.5142, -29.3064], [-20.5142, -29.3064], [-20.5142, -29.3064], [-20.5142, -29.3064], [-20.5, -29.32], [-20.5, -29.32], [-20.5, -29.32], [-22.716666699999998, -1.45], [-14.083333300000001, -5.3672223], [-14.633333300000002, -5.5008333], [-21.9333333, -4.1833333], [-14.116666699999998, -5.
key = '0573d875005f45bebe452ff81c26b684'
geocoder = OpenCageGeocode(key)

results = geocoder.reverse_geocode(busca2[0], busca2[1])
pprint(results)
if results and len(results):
        print(results[0]['formatted'])

a1 = results[0]['geometry']['lat']
a2 = results[0]['geometry']['lng']

from ipyleaflet import *

center = (a1, a2)
map = Map(center=center, zoom=12)
marker = Marker(location=center, draggable=False)
map.add_layer(marker)
map
# Out:
# [{'annotations': {'DMS': {'lat': "3° 50' 57.54264'' S",
#                           'lng': "32° 25' 11.83296'' W"},
#                   'MGRS': '25MER6440174506',
#                   'Maidenhead': 'HI36sd96od',
#                   'Mercator': {'x': -3608972.726, 'y': -425960.325},
#                   'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=30687893#map=16/-3.84932/-32.41995',
#                           'url': 'https://www.openstreetmap.org/?mlat=-3.84932&mlon=-32.41995#map=16/-3.84932/-32.41995'},
#                   'UN_M49': {'regions': {'AMERICAS': '019',
#                                          'BR': '076',
#                                          'LATIN_AMERICA': '419',
#                                          'SOUTH_AMERICA': '005',
#                                          'WORLD': '001'},
#                              'statistical_groupings': ['LEDC']},
#                   'callingcode': 55,
#                   'currency': {'decimal_mark': ',',
#                                'html_entity': 'R$',
#                                'iso_code': 'BRL',
#                                'iso_numeric': '986',
#                                'name': 'Brazilian Real',
#                                'smallest_denomination': 5,
#                                'subunit': 'Centavo',
#                                'subunit_to_unit': 100,
#                                'symbol': 'R$',
#                                'symbol_first': 1,
#                                'thousands_separator': '.'},
#                   'flag': '🇧🇷',
#                   'geohash': '7r2fn728074rr38cvk7g',
#                   'qibla': 66.61,
#                   'roadinfo': {'drive_on': 'right',
#                                'road': 'Rua Primavera',
#                                'road_type': 'track',
#                                'speed_in': 'km/h'},
#                   'sun': {'rise': {'apparent': 1571384880,
#                                    'astronomical': 1571380680,
#                                    'civil': 1571383620,
#                                    'nautical': 1571382180},
#                           'set': {'apparent': 1571428800,
#                                   'astronomical': 1571433060,
#                                   'civil': 1571430120,
#                                   'nautical': 1571431560}},
#                   'timezone': {'name': 'America/Noronha',
#                                'now_in_dst': 0,
#                                'offset_sec': -7200,
#                                'offset_string': '-0200',
#                                'short_name': '-02'},
#                   'what3words': {'words': 'retains.fizzles.trees'}},
#   'bounds': {'northeast': {'lat': -3.8493174, 'lng': -32.4198412},
#              'southwest': {'lat': -3.8495788, 'lng': -32.4199536}},
#   'components': {'ISO_3166-1_alpha-2': 'BR',
#                  'ISO_3166-1_alpha-3': 'BRA',
#                  '_type': 'road',
#                  'continent': 'South America',
#                  'country': 'Brazil',
#                  'country_code': 'br',
#                  'county': 'Microrregião de Fernando de Noronha',
#                  'island': 'Fernando de Noronha',
#                  'postcode': '53990-000',
#                  'road': 'Rua Primavera',
#                  'road_type': 'track',
#                  'state': 'Pernambuco',
#                  'state_code': 'PE',
#                  'state_district': 'Mesorregião Metropolitana de Recife',
#                  'suburb': 'Vila da Vacaria'},
#   'confidence': 9,
#   'formatted': 'Rua Primavera, Mesorregião Metropolitana de Recife - PE, '
#                '53990-000, Brazil',
#   'geometry': {'lat': -3.8493174, 'lng': -32.4199536}}]
# Rua Primavera, Mesorregião Metropolitana de Recife - PE, 53990-000, Brazil
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
